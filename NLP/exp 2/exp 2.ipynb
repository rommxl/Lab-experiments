# %%
import pandas as pd
import nltk

# %%
data = pd.read_csv('./reviews.csv')
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
data['review'] = data['review'].str.replace(r'[^A-Za-z0-9]',' ',regex=True)
data['review'] = data['review'].str.replace(r'\s+',' ',regex=True)
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production br br The filmin...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there s a family where a little boy ...  negative
# 4  Petter Mattei s Love in the Time of Money is a...  positive

# %%
reviews = data['review']

# %%
def stemWords(data, stemmer):

    original = []
    root = []

    for sentence in data['review']:
        sentence = sentence.split(' ')
        for word in sentence:
            original.append(word)
            root.append(stemmer.stem(word))
    stemmed = pd.DataFrame({'Original':original,'Root Word':root})
    return stemmed

# %%
#Using snowball stemmer
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

# %%
original = []
root = []
for sentence in data['review']:
    sentence = sentence.split(' ')
    for word in sentence:
        original.append(word)
        root.append(stemmer.stem(word))
stemmed = pd.DataFrame({'Original':original,'Root Word':root})
stemmed
# Out:
#            Original Root Word
# 0               One       one
# 1                of        of
# 2               the       the
# 3             other     other
# 4         reviewers    review
# ...             ...       ...
# 12027830   channels   channel
# 12027831      avoid     avoid
# 12027832       this      this
# 12027833      movie      movi
# 12027834
#
# [12027835 rows x 2 columns]

# %%
from nltk.corpus import wordnet

def get_word_forms(word):
    synsets = wordnet.synsets(word)
    forms = set()

    for synset in synsets:
        for lemma in synset.lemmas():
            forms.add(lemma.name())

    return forms

for word in stemmed['Root Word']:
    word_forms = get_word_forms(word)

    print(f"Different forms of '{word}': {word_forms}")
