# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("tips.csv")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(df1['total_bill'],df1['tip'])

# %%
plt.scatter(df1['total_bill'],df1['tip'],alpha=0.5,marker='d')

# %%
sns.scatterplot(x='total_bill', y='tip',data=df1,hue='day')
# Out:
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.regplot(x='total_bill',y='tip',data = df1)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.hist(df1['total_bill'],bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(x=df1['day'],edgecolor = 'Orange', color='cyan')
# Out:
# (array([76.,  0.,  0., 87.,  0.,  0., 62.,  0.,  0., 19.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data = df1, x='day', hue='sex')
# Out:
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df1.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.countplot(x='day',data = df1, palette='Set3')
# Out:
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='day', ylabel='count'>

# %%
df1.groupby('day')

# %%
sns.barplot(x='day',y='total_bill',data = df1)
# Out:
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
a = pd.DataFrame(df1['day'])
a['index'] = a.index
a
# Out:
#       day  index
# 0     Sun      0
# 1     Sun      1
# 2     Sun      2
# 3     Sun      3
# 4     Sun      4
# ..    ...    ...
# 239   Sat    239
# 240   Sat    240
# 241   Sat    241
# 242   Sat    242
# 243  Thur    243
#
# [244 rows x 2 columns]

# %%
plt.pie(df1['day'].value_counts(),labels = df1['day'].value_counts(), autopct='%1.2f',explode=[0.2,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x209f48e6290>,
# ...
#  [Text(0.5662022786945966, 1.1702200560582812, '87'),
#   Text(-1.0967192869113325, -0.08489290734035711, '76'),
#   Text(0.3074340394718734, -1.0561649072820052, '62'),
#   Text(1.06724906774893, -0.2664196452760947, '19')],
#  [Text(0.34843217150436717, 0.7201354191127883, '35.66'),
#   Text(-0.598210520133454, -0.04630522218564932, '31.15'),
#   Text(0.16769129425738546, -0.5760899494265482, '25.41'),
#   Text(0.5821358551357799, -0.14531980651423346, '7.79')])

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize = (10,5))
ax[0,0].pie(df1['day'].value_counts(),labels = df1['day'].value_counts(), autopct='%1.2f',explode=[0.2,0,0,0])
ax[0,1].hist(x = df1['day'])
# Out:
# (array([76.,  0.,  0., 87.,  0.,  0., 62.,  0.,  0., 19.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)
