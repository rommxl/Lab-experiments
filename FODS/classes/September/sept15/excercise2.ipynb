# %%
import pandas as pd
import numpy as np

# %%
technologies = pd.DataFrame({
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas","Hadoop","Spark","Python","NA"],
    'Fee' :[22000,25000,23000,24000,26000,25000,25000,22000,1500],
    'Duration':['30days','50days','55days','40days','60days','35days','30days','50days','40days'],
    'Discount':[1000,2300,1000,1200,2500,None,1400,1600,0]
          })

# %%
technologies.dtypes
# Out:
# Courses      object
# Fee           int64
# Duration     object
# Discount    float64
# dtype: object

# %%
result = technologies.groupby("Courses").aggregate({"Duration":"count","Fee":['min','max']})

# %%
result
# Out:
#         Duration    Fee
#            count    min    max
# Courses
# Hadoop         2  23000  25000
# NA             1   1500   1500
# Pandas         1  26000  26000
# PySpark        1  25000  25000
# Python         2  22000  24000
# Spark          2  22000  25000

# %%
df2 = pd.DataFrame({'Student Names' : ['Jenny', 'Singh', 'Charles', 'Richard', 'Veena'],
                   'Category' : ['Online', 'Offline', 'Offline', 'Offline', 'Online'],
                   'Gender' : ['Female', 'Male', 'Male', 'Male', 'Female'],
                  'Courses': ['Java', 'Spark', 'PySpark','Hadoop','C'],
                   'Fee': [15000, 17000, 27000, 29000, 12000],
                   'Discount': [1100, 800, 1000, 1600, 600]})

df2
# Out:
#   Student Names Category  Gender  Courses    Fee  Discount
# 0         Jenny   Online  Female     Java  15000      1100
# 1         Singh  Offline    Male    Spark  17000       800
# 2       Charles  Offline    Male  PySpark  27000      1000
# 3       Richard  Offline    Male   Hadoop  29000      1600
# 4         Veena   Online  Female        C  12000       600

# %%
p_table = pd.pivot_table(df2,index=['Gender'],aggfunc={"Fee":"mean","Discount":"sum"})
p_table
# Out:
#         Discount           Fee
# Gender
# Female      1700  13500.000000
# Male        3400  24333.333333

# %%
p_table = pd.pivot_table(df2,index=['Gender'],values=['Discount'],aggfunc='mean')
p_table
# Out:
#            Discount
# Gender
# Female   850.000000
# Male    1133.333333

# %%
p_table = pd.pivot_table(df2,index=['Gender'],columns=['Fee'],values=['Discount'],aggfunc='mean')
p_table
# Out:
#        Discount
# Fee       12000   15000  17000   27000   29000
# Gender
# Female    600.0  1100.0    NaN     NaN     NaN
# Male        NaN     NaN  800.0  1000.0  1600.0

# %%
titanic = pd.read_csv(r"C:\Users\Rommel\OneDrive\Desktop\Coding\Academic\FODS\sept14\titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
