# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df=df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 102   32            86000          0
# 108   26            86000          0
# 123   35            53000          0
# 75    34           112000          1
# 267   37            74000          0

# %%
x = df.drop('Purchased',axis=1)
y = df['Purchased']

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=100)

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
scale.fit(xtrain)

xtrain_scaled = scale.transform(xtrain)
xtest_scaled = scale.transform(xtest)

# %%
# saclar mean
scale.mean_
# Out:
# array([3.75107143e+01, 7.10750000e+04])

# %%
xtrain
# Out:
#      Age  EstimatedSalary
# 234   38           112000
# 45    23            20000
# 171   34           115000
# 47    27            54000
# 265   42           108000
# ..   ...              ...
# 343   47            51000
# 359   42            54000
# 323   48            30000
# 280   59            88000
# 8     25            33000
#
# [280 rows x 2 columns]

# %%
xtrain_scaled
# Out:
# array([[ 4.68359482e-02,  1.14942217e+00],
#        [-1.38901064e+00, -1.43449573e+00],
#        [-3.36056475e-01,  1.23368037e+00],
#        [-1.00611821e+00, -4.79569545e-01],
#        [ 4.29728371e-01,  1.03707792e+00],
#        [-5.27502686e-01,  8.12389405e-01],
#        [ 1.09979011e+00, -9.85118699e-01],
#        [-1.44610263e-01,  1.10237802e-01],
#        [-5.27502686e-01,  1.28985249e+00],
#        [-1.10184132e+00,  2.78754186e-01],
#        [-2.40333369e-01,  7.28131212e-01],
#        [ 1.86557496e+00,  1.43028282e+00],
#        [-4.88871576e-02, -3.95311353e-01],
#        [-7.18948898e-01,  4.47270571e-01],
#        [ 1.09979011e+00, -1.20980721e+00],
#        [-2.40333369e-01, -1.37832360e+00],
#        [-2.40333369e-01, -1.23789328e+00],
#        [-4.88871576e-02,  1.10237802e-01],
#        [-1.00611821e+00, -1.12554902e+00],
#        [ 1.19551322e+00, -7.60430186e-01],
#        [ 1.00406701e+00,  8.21517376e-02],
#        [-1.10184132e+00,  2.50668122e-01],
#        [ 8.12620794e-01, -1.37832360e+00],
#        [-1.10184132e+00, -1.57492605e+00],
#        [ 8.12620794e-01,  8.21517376e-02],
#        [-1.44610263e-01, -3.11053160e-01],
#        [-1.29328753e+00, -3.67225288e-01],
#        [-4.88871576e-02,  1.66409930e-01],
#        [ 1.48268253e+00, -1.04129083e+00],
#        [ 1.09979011e+00,  5.03442699e-01],
#        [ 3.34005265e-01, -1.15363508e+00],
#        [-4.31779580e-01, -5.63827737e-01],
#        [ 1.09979011e+00, -1.20980721e+00],
#        [ 2.05702117e+00,  2.02009016e+00],
#        [-1.77190306e+00, -1.40640966e+00],
#        [-7.18948898e-01, -1.51875392e+00],
#        [ 4.29728371e-01, -4.79569545e-01],
#        [-1.19756443e+00,  5.31528764e-01],
#        [-2.40333369e-01, -3.39139224e-01],
#        [ 1.48268253e+00,  3.06840251e-01],
#        [-1.00611821e+00, -1.51875392e+00],
#        [ 1.76985185e+00,  1.73922952e+00],
#        [-1.58045685e+00, -1.54683998e+00],
#        [-7.18948898e-01,  1.79540165e+00],
#        [ 5.25451477e-01,  1.62688526e+00],
#        [-5.27502686e-01,  1.37411069e+00],
#        [-1.58045685e+00,  2.59796093e-02],
#        [-1.10184132e+00, -7.88516250e-01],
#        [ 1.96129806e+00,  2.04817623e+00],
#        [-4.88871576e-02, -5.35741673e-01],
#        [-4.31779580e-01, -7.88516250e-01],
#        [ 5.25451477e-01,  1.73922952e+00],
#        [-2.40333369e-01, -4.51483481e-01],
#        [-1.77190306e+00, -3.01925189e-02],
#        [-6.23225792e-01,  5.03442699e-01],
#        [-1.38901064e+00, -2.26794968e-01],
#        [ 1.19551322e+00, -1.43449573e+00],
#        [-7.18948898e-01,  1.26176643e+00],
#        [-1.77190306e+00,  1.38323866e-01],
#        [-1.00611821e+00,  4.75356635e-01],
#        [ 1.38695943e+00,  2.21669261e+00],
#        [ 1.29123632e+00,  2.10434835e+00],
#        [-1.86762617e+00, -8.63646472e-02],
#        [ 4.29728371e-01,  9.24733661e-01],
#        [-6.23225792e-01, -1.57492605e+00],
#        [-1.29328753e+00, -4.51483481e-01],
#        [-8.14672003e-01, -1.20980721e+00],
#        [-7.18948898e-01,  1.00899185e+00],
#        [-1.48473374e+00, -1.49066785e+00],
#        [ 1.57840564e+00,  9.24733661e-01],
#        [ 4.29728371e-01,  2.22582058e-01],
#        [ 2.38282160e-01,  2.59796093e-02],
#        [-7.18948898e-01,  5.03442699e-01],
#        [-1.44610263e-01, -1.06937689e+00],
#        [ 4.29728371e-01,  2.18860655e+00],
#        [ 1.42559054e-01,  1.76731559e+00],
#        [-1.86762617e+00,  3.06840251e-01],
#        [-1.44610263e-01,  1.54262707e+00],
#        [-1.29328753e+00, -1.46258179e+00],
#        [-2.40333369e-01, -1.35023753e+00],
#        [-1.44610263e-01,  7.84303341e-01],
#        [ 4.68359482e-02,  1.17750824e+00],
#        [-1.10184132e+00, -1.51875392e+00],
#        [ 9.08343900e-01, -5.63827737e-01],
#        [ 4.29728371e-01, -4.79569545e-01],
#        [ 1.00406701e+00, -1.15363508e+00],
#        [ 2.05702117e+00,  4.75356635e-01],
#        [-1.19756443e+00, -1.06937689e+00]])

# %%
xtrain_scaled = pd.DataFrame(xtrain_scaled, columns=xtrain.columns)
xtest_scaled = pd.DataFrame(xtest_scaled, columns=xtest.columns)

# %%
np.round(xtrain.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.5          71075.0
# std     10.5          35668.6
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          89250.0
# max     60.0         150000.0

# %%
np.round(xtrain_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    -0.0             -0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.7             -0.8
# 50%     -0.0             -0.0
# 75%      0.8              0.5
# max      2.2              2.2

# %% [markdown]
# # Effect of Scaling
# #Plot before after effect of every column applied standardiazation

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(12, 5))
ax1.scatter(xtrain['Age'],xtrain['EstimatedSalary'],color = 'red')
ax2.scatter(xtrain_scaled['Age'],xtrain_scaled['EstimatedSalary'])
#Plot before after effect of every column applied standardiazation

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title("Before scaling")
sns.kdeplot(xtrain['EstimatedSalary'],ax=ax1,color='red')
sns.kdeplot(xtrain['Age'],ax = ax1)
# after scaling
ax1.set_title("After scaling")
sns.kdeplot(xtrain_scaled['EstimatedSalary'],ax=ax2,color='red')
sns.kdeplot(xtrain_scaled['Age'],ax = ax2)
plt.show()
# Out:
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Comparison of Distributions
# Every individual columns kde plot of before after effect

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling


# after scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling


# after scaling

# %% [markdown]
# # Why scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
lr_scaled.fit(xtrain_scaled,ytrain)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(xtest)
y_pred_scaled = lr_scaled.predict(xtest_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(ytest,y_pred))
print("Scaled",accuracy_score(ytest,y_pred_scaled))
# Out:
# Actual 0.625
# Scaled 0.8416666666666667

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
dt_scaled.fit(xtrain_scaled,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(xtest)
y_pred_scaled = dt_scaled.predict(xtest_scaled)

# %%
print("Actual",accuracy_score(ytest,y_pred))
print("Scaled",accuracy_score(ytest,y_pred_scaled))
# Out:
# Actual 0.875
# Scaled 0.875

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# # Effect of Outlier

# %%
df = df.append(pd.DataFrame({'Age':[5,90,95],'EstimatedSalary':[1000,250000,350000],'Purchased':[0,1,1]}),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10936\2365817244.py in ?()
# ----> 1 df = df.append(pd.DataFrame({'Age':[5,90,95],'EstimatedSalary':[1000,250000,350000],'Purchased':[0,1,1]}),ignore_index=True)
#
# c:\Users\Rommel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6198             and name not in self._accessors
#    6199             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200         ):
#    6201             return self[name]
# -> 6202         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(df.drop('Purchased', axis=1),
                                                    df['Purchased'],
                                                    test_size=0.3,
                                                    random_state=0)

xtrain.shape, xtest.shape

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(xtrain)

# transform train and test sets
xtrain_scaled = scaler.transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# %%
xtrain_scaled = pd.DataFrame(xtrain_scaled, columns=xtrain.columns)
xtest_scaled = pd.DataFrame(xtest_scaled, columns=xtest.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(xtrain['Age'], xtrain['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(xtrain_scaled['Age'], xtrain_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
