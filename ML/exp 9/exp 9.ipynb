# %% [markdown]
# **Name**: *Bodhisatya Ghosh*<br/>
# **UID**: *2021700026*<br/>
# **Branch**: *CSE DS*<br/>
# **Experiment**: *9*<br/>

# %% [markdown]
# Principal Component Analysis (PCA):
# PCA is a statistical procedure that transforms a set of correlated variables into a set of linearly uncorrelated variables called principal components. These principal components are ordered in such a way that the first component explains the maximum variance in the data, the second component explains the maximum variance remaining after accounting for the first component, and so on. By retaining only a subset of these principal components that capture most of the variance, PCA effectively reduces the dimensionality of the data while preserving as much information as possible.
#
# Singular Value Decomposition (SVD):
# SVD is a matrix factorization technique that decomposes a matrix into three matrices: U, Σ, and Vᵀ, where U and V are orthogonal matrices and Σ is a diagonal matrix containing the singular values of the original matrix. SVD is widely used in various applications, including data compression, noise reduction, and dimensionality reduction. In the context of dimensionality reduction, SVD can be used to find a low-rank approximation of the original data matrix by retaining only the most significant singular values and their corresponding singular vectors.
#
# Both PCA and SVD are closely related, with PCA often being implemented using SVD internally. PCA finds the principal components by performing SVD on the covariance matrix of the data, while SVD directly decomposes the data matrix itself. However, both techniques achieve similar goals of reducing the dimensionality of the data while preserving important information.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from numpy.linalg import svd

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
U, Sigma, VT = svd(X_scaled)

# %%
X_svd = X_scaled.dot(VT.T[:, :2])

# %%
# Plot PCA results
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.title("PCA")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot SVD results
plt.subplot(1, 2, 2)
plt.scatter(X_svd[:, 0], X_svd[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.title("SVD")
plt.xlabel("SV1")
plt.ylabel("SV2")

plt.show()
