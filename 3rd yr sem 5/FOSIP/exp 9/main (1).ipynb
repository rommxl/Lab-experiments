# %% [markdown]
# ### 1. Importing Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_sample_image

# %% [markdown]
# ### 2. Read the image

# %%
flower = load_sample_image("flower.jpg")

# %% [markdown]
# ### 3. Convert the image to grayscale

# %%
flower_gray = cv2.cvtColor(flower, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### 4. Apply morphological operations

# %%
kernel_size = 5
kernel = np.ones((kernel_size, kernel_size), np.uint8)

# %% [markdown]
# #### a. Erosion

# %%
erosion = cv2.erode(flower_gray, kernel, iterations=1)

# %% [markdown]
# #### b. Dilation

# %%
dilation = cv2.dilate(flower_gray, kernel, iterations=1)

# %% [markdown]
# #### c. Opening

# %%
opening = cv2.morphologyEx(flower_gray, cv2.MORPH_OPEN, kernel)

# %% [markdown]
# ### d. Closing

# %%
closing = cv2.morphologyEx(flower_gray, cv2.MORPH_CLOSE, kernel)

# %% [markdown]
# ### 5. Display the results

# %%
plt.figure(figsize=(10, 8))

plt.subplot(2, 3, 1), plt.imshow(flower_gray, cmap='gray')
plt.title('Original Image'), plt.axis('off')

plt.subplot(2, 3, 2), plt.imshow(erosion, cmap='gray')
plt.title('Erosion'), plt.axis('off')

plt.subplot(2, 3, 3), plt.imshow(dilation, cmap='gray')
plt.title('Dilation'), plt.axis('off')

plt.subplot(2, 3, 4), plt.imshow(opening, cmap='gray')
plt.title('Opening'), plt.axis('off')

plt.subplot(2, 3, 5), plt.imshow(closing, cmap='gray')
plt.title('Closing'), plt.axis('off')

plt.show()
