# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_sample_image
from sklearn.utils import shuffle
import warnings

# %% [markdown]
# ### 2. Ignoring Warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 3. Loading Sample Image

# %%
flower = load_sample_image("flower.jpg")
flower = np.array(flower, dtype=np.float64) / 255

# %%
width, height, channels = flower.shape
image_array = np.reshape(flower, (width * height, channels))

# %% [markdown]
# ### 4. Segmentation

# %%
n_colors = 3  
image_array_sample = shuffle(image_array, random_state=0)[:1000] 
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

# %%
segmented_image = labels.reshape(width, height)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(flower)
plt.axis("off")

plt.subplot(1, 2, 2)
plt.title("Segmented Image (k-means)")
plt.imshow(segmented_image, cmap=plt.cm.nipy_spectral)
plt.axis("off")

plt.show()
